# %%
 # 1. you have to write a fun which will take string and return a len of it without using a inbuilt fun len
    
def getlength():
    ip_str = input("Please enter a string: ")
    if type(ip_str) == str:
        count = 0
        for i in ip_str:
            count = count + 1
    return count

# %%
getlength()
# Out:
# Please enter a string: arae
# 4

# %%
 # 2. write a fun which will be able to print an index of all premitive element which you will pass
def printIndex(*l):
    count=0
    for i in l:
        if type(i) == int or type(i) == str or type(i) == list or type(i) == tuple:
            print(f'Index of {i} is {count}')
            count+=1

# %%
printIndex(123,45,"arae",74,"21",(22,34),[22,44,55])
# Out:
# Index of 123 is 0
# Index of 45 is 1
# Index of arae is 2
# Index of 74 is 3
# Index of 21 is 4
# Index of (22, 34) is 5
# Index of [22, 44, 55] is 6

# %%
# 3. Write a fun which will take input as a dict and give me out as a list of all the values
     #even in case of 2 level nesting it should work.
def fun3(dg1):
    lst=[]
    fun3b(dg1,lst)
    return lst

def fun3a(dg2):
    return dg2.values()

def fun3b(dg2,lst):
    if type(dg2)==dict:
        a=fun3a(dg2)
        for i in a:
            if type(i)==dict:
                b=fun3b(i,lst)
            else:
                lst.append(i)
    
    return lst

# %%
fun3({"a":4,"b":5,"c":{"d":7,"e":8,"f":{"g":5,"h":9,"i":{"j":5,"k":9}}}})
# Out:
# [4, 5, 7, 8, 5, 9, 5, 9]

# %%
# 4. write a fun which will take another function as an input and return me an output

def getValues(take_inp):
    return take_inp
def take_inp():
    inp_val = input("Enter your name: ")
    return inp_val

# %%
getValues(take_inp())
# Out:
# Enter your name: alaga
# 'alaga'

# %%
# 5. write a function which will take list as a input and give me concatnation of all the element as output 
def func(*ar):
    l=[]
    for i in ar:
        if type(i)==list:
            l=l+i
    return l

# %%
func([1,2,3,4],["a","b","c","d"],[11,1,2,33],"sudh","abc")
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c', 'd', 11, 1, 2, 33]

# %%
# 6 write a function which will be able to take a list as an input return an index of each element
  # like a inbuilt index function but even if we have repetative element it should return index
def printIndex(lst):
    if type(lst) == list:    
        for i in range(len(lst)):
            print('Index of ',lst[i],' is ',i)
# Out:
# Index of  1  is  0
# Index of  2  is  1
# Index of  4  is  2
# Index of  5  is  3
# Index of  6  is  4
# Index of  5  is  5

# %%
printIndex([1,2,4,5,6,5])

# %%
# 7. Write a function which will whould return list of all the file name from a directory.

import os
def getFileName(in_path):
    return os.listdir(in_path)

getFileName('C:\\Users\\algates')
# Out:
# ['.anaconda',
#  '.android',
#  '.argouml',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.vscode',
#  '3D Objects',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'PycharmProjects',
#  'Python Basic Assignment 1.ipynb',
#  'python basic assignment 2.ipynb',
#  'Python Basic Assignment 3.ipynb',
#  'Python Basic Assignment 4.ipynb',
#  'Python Holiday Assignment.ipynb',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Videos']

# %%
# 8 . write a function which will be able to show your system configuration .

def func8():
    import platform as pl
    return pl.uname()

func8()
# Out:
# uname_result(system='Windows', node='LAPTOP-T0QODKTU', release='10', version='10.0.19041', machine='AMD64', processor='AMD64 Family 23 Model 104 Stepping 1, AuthenticAMD')

# %%
 # 9 write a function which will be able to show date and time
    
import datetime as dt
def getDateTime():
    dateTime = dt.datetime.now()
    print(dateTime)
getDateTime()
# Out:
# 2022-02-20 19:23:22.601220

# %%
# 10 write a function whihc will be able to read a image file and show it to you.

from PIL import Image
def getImage(fileName):
    img = Image.open(fileName,'r')
    return display(img)
fileName = input('Enter the pngfile name along with extension: ')
getImage(fileName)
# Out:
# Enter the pngfile name along with extension: whimage.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=957x600 at 0x150ED039CD0>

# %%
pip install opencv-python

# %%
# 11. write a function which can read video file and play for you.
import cv2

def playVideo(video_path):
    video = cv2.VideoCapture(video_path)
    while (video.isOpened()):
        # capturing the video frame-by-frame
        ret, frame = video.read()
        if ret == True:
            cv2.imshow('Frame',frame)  
            if cv2.waitKey(25) & 0xFF == ord('x'):
                break
        else:
            break
    video.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b6b1a71d9a22> in <module>
#       1 # 11. write a function which can read video file and play for you.
# ----> 2 import cv2
#       3
#       4 def playVideo(video_path):
#       5     video = cv2.VideoCapture(video_path)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# 12 . write a function whihc can move a file from one directory to another directory 
import shutil
def moveFile(src_path,dst_path):
    shutil.move(src_path,dst_path)

src_path = input("Enter the source directory path: ")
dst_path = input("Enter the destination directory path")

moveFile(src_path,dst_path)

# %%
# 13 write a function which will be able to shutdown your system. 

import os
def offSystem():
    return os.system("shutdown /s /t 1")

#offSystem()

# %%
# 14. write a function whihc will be able to access your mail.
import easyimap as e

def getEmails(user,passwd,mailNo=0):
    server = e.connect('imap.gmail.com',user,passwd)
    mail = server.mail(server.listids()[mailNo])
    print("Sender: \n",mail.from_addr)
    print("Title: ",mail.title)
    print("Body: ",mail.body)
    
user = "sk5170067@gmail.com"
passwd = ''
getEmails(user,passwd)

# %%
# 15. write a func by which i can send a mail to anyone

import smtplib
def sendEmail(user,passwd):
    server = smtplib.SMTP('smtp.gmail.com',587)
    server.starttls()
    server.login(user,passwd)
    rx_mail = input("enter receiver mail id: ")
    msg = input("enter the mail(body)")
    server.sendmail(user,rx_mail,msg)
    server.close()
    print("task completed")

user = "sk5170067@gmail.com"
passwd = ''
sendEmail(user,passwd)

# %%
# 16. write a func to read a complete PDf file .

import PyPDF2 as pdf
def readFile(filename):
    f = open(filename+'.pdf','rb')
    f_read = pdf.PdfFileReader(f)
    f_page = f_read.getPage(0)
    print(f_page.extractText())
    f.close()
    
inp_filename = input("enter your file name: ")    
readFile(inp_filename)

# %%
# 17. write a function to read a word file

def readDoc(fileName):
    f = open(fileName,'r')
    print(f.read())
    
Fname = input("enter your file name with .doc extension: ")
readDoc(Fname)

# %%
# 18 write a function which can help you to filter only word file from a directory

import os
def getWordFiles2():
    for file in os.listdir("C:\\Users\\Alagu\\Working_space\\class\python"):
        if file.endswith((".doc",".docx")):
            print(os.path.join(file))
            
            
getWordFiles2()

# %%
# 19 write a function by which you can print an ip address of your system

import socket
def getIPAdd():
    hostname = socket.gethostname()
    IPAddr = socket.gethostbyname(hostname)
    print("Your Computer Name is:" + hostname)
    print("Your Computer IP Address is:" + IPAddr)
getIPAdd()
# Out:
# Your Computer Name is:LAPTOP-T0QODKTU
# Your Computer IP Address is:192.168.142.196

# %%
# 20. write a function by which you will be able to append two PDF files.

from PyPDF2 import PdfFileMerger
def mergePDF(pdf1_path,pdf2_path,outfile_path):
    pdfs = ['Merged-GOI-guidelines.pdf', 'Merged-GOI-guidelines.pdf']
    merger = PdfFileMerger()
    for pdf in pdfs:
        merger.append(open(pdf,"rb"))
    with open(outfile_path,"wb") as fileout:
        merger.write("result.pdf")
        #merger.close()  

pdf1_path=""
pdf2_path=""
outfile_path=""

mergePDF(pdf1_path,pdf2_path,outfile_path)
